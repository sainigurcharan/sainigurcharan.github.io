# %%
import pandas as pd

# %%
citiesDF = pd.read_csv('Resources/cities.csv')
del citiesDF['Unnamed: 0']
citiesDF.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0       Rikitea         100      PF  1569893650        81    -23.12
# 1     Carnarvon           0      ZA  1569893744        83    -30.97
# 2      Shirokiy          69      RU  1569893746        97     53.87
# 3  Vysokogornyy          84      RU  1569893747        65     50.10
# 4        Bethel           1      US  1569893748        62     60.79
#
#    Longitude  Max Temp  Wind Speed
# 0    -134.97     68.81       17.65
# 1      22.13     41.99        8.16
# 2      39.17     55.99        5.01
# 3     139.13     52.07        5.46
# 4    -161.76     51.80       11.41

# %%
htmlTable = citiesDF.to_html()
print(htmlTable)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Rikitea</td>
#       <td>100</td>
#       <td>PF</td>
#       <td>1569893650</td>
#       <td>81</td>
#       <td>-23.12</td>
#       <td>-134.97</td>
#       <td>68.81</td>
#       <td>17.65</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Carnarvon</td>
#       <td>0</td>
#       <td>ZA</td>
#       <td>1569893744</td>
#       <td>83</td>
#       <td>-30.97</td>
#       <td>22.13</td>
#       <td>41.99</td>
#       <td>8.16</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Shirokiy</td>
#       <td>69</td>
#       <td>RU</td>
#       <td>1569893746</td>
# ...

# %%
citiesDF.to_html('Resources/table.html')
